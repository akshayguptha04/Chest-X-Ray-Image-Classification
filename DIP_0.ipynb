# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("tawsifurrahman/covid19-radiography-database")

print("Path to dataset files:", path)
# Out:
# Downloading from https://www.kaggle.com/api/v1/datasets/download/tawsifurrahman/covid19-radiography-database?dataset_version_number=5...
# 100%|██████████| 778M/778M [00:36<00:00, 22.3MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/tawsifurrahman/covid19-radiography-database/versions/5

# %%
import os
import numpy as np
import pandas as pd
from PIL import Image
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.preprocessing.image import img_to_array
from matplotlib import pyplot as plt

# %%
# Set the base path for the dataset

base_path = "/root/.cache/kagglehub/datasets/tawsifurrahman/covid19-radiography-database/versions/5/COVID-19_Radiography_Dataset"


# Define subsets
subsets = ["COVID", "Lung_Opacity", "Normal", "Viral Pneumonia"]

# %%
# Initialize lists for data and labels
data = []
labels = []

# Define image size for resizing
img_size = (128, 128)

# Load images and labels
for subset in subsets:
    image_dir = os.path.join(base_path, subset, "images")
    if os.path.exists(image_dir):
        image_files = os.listdir(image_dir)
        print(f"{subset}: Found {len(image_files)} images.")

        for image_name in image_files:
            image_path = os.path.join(image_dir, image_name)
            try:
                # Load and preprocess the image
                img = Image.open(image_path).convert("L")  # Convert to grayscale
                img = img.resize(img_size)
                img_array = img_to_array(img) / 255.0  # Normalize
                data.append(img_array)
                labels.append(subset)
            except Exception as e:
                print(f"Error loading image {image_path}: {e}")
    else:
        print(f"{subset}: No directory found.")

# Debug: Check if data and labels are populated
print(f"Number of samples: {len(data)}")
print(f"Number of labels: {len(labels)}")
print(f"Unique labels: {set(labels)}")
# Out:
# COVID: Found 3616 images.
# Lung_Opacity: Found 6012 images.
# Normal: Found 10192 images.
# Viral Pneumonia: Found 1345 images.
# Number of samples: 21165
# Number of labels: 21165
# Unique labels: {'COVID', 'Normal', 'Viral Pneumonia', 'Lung_Opacity'}

# %%
# Convert data and labels to numpy arrays
data = np.array(data, dtype="float32")
labels = np.array(labels)

# Encode labels
label_encoder = LabelEncoder()
labels_encoded = label_encoder.fit_transform(labels)
labels_categorical = to_categorical(labels_encoded)

# %%
# Split into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(data, labels_categorical, test_size=0.2, random_state=42)

# %%
model = Sequential([
    Conv2D(16, (3, 3), activation='relu', input_shape=(128, 128, 1)),
    MaxPooling2D(pool_size=(2, 2)),

    Conv2D(64, (3, 3), activation='relu', padding='same'),
    MaxPooling2D(pool_size=(2, 2)),
    Dropout(0.25),

    Conv2D(128, (3, 3), activation='relu', padding='same'),
    MaxPooling2D(pool_size=(2, 2)),
    Dropout(0.3),

    Conv2D(128, (3, 3), activation='relu', padding='same'),
    MaxPooling2D(pool_size=(2, 2)),
    Dropout(0.4),

    Flatten(),

    Dense(128, activation='relu'),
    Dropout(0.25),

    Dense(64, activation='relu'),

    Dense(4, activation='softmax')
])
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
from tensorflow.keras.metrics import Precision
 #Compile the model
model.compile(optimizer="adam", loss="categorical_crossentropy", metrics=["accuracy", Precision()])

# Train the model
history = model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=10, batch_size=32)
# Out:
# Epoch 1/10
# 530/530 ━━━━━━━━━━━━━━━━━━━━ 20s 27ms/step - accuracy: 0.9109 - loss: 0.2375 - precision_1: 0.9145 - val_accuracy: 0.8904 - val_loss: 0.2794 - val_precision_1: 0.8976
# Epoch 2/10
# 530/530 ━━━━━━━━━━━━━━━━━━━━ 8s 16ms/step - accuracy: 0.9159 - loss: 0.2250 - precision_1: 0.9195 - val_accuracy: 0.8982 - val_loss: 0.2809 - val_precision_1: 0.9016
# Epoch 3/10
# 530/530 ━━━━━━━━━━━━━━━━━━━━ 10s 16ms/step - accuracy: 0.9171 - loss: 0.2156 - precision_1: 0.9207 - val_accuracy: 0.9046 - val_loss: 0.2726 - val_precision_1: 0.9078
# Epoch 4/10
# 530/530 ━━━━━━━━━━━━━━━━━━━━ 8s 16ms/step - accuracy: 0.9196 - loss: 0.2159 - precision_1: 0.9229 - val_accuracy: 0.9005 - val_loss: 0.2759 - val_precision_1: 0.9045
# Epoch 5/10
# 530/530 ━━━━━━━━━━━━━━━━━━━━ 10s 16ms/step - accuracy: 0.9197 - loss: 0.2197 - precision_1: 0.9226 - val_accuracy: 0.9036 - val_loss: 0.2646 - val_precision_1: 0.9062
# Epoch 6/10
# 530/530 ━━━━━━━━━━━━━━━━━━━━ 10s 16ms/step - accuracy: 0.9285 - loss: 0.1994 - precision_1: 0.9302 - val_accuracy: 0.8972 - val_loss: 0.2743 - val_precision_1: 0.9005
# Epoch 7/10
# 530/530 ━━━━━━━━━━━━━━━━━━━━ 8s 15ms/step - accuracy: 0.9309 - loss: 0.1883 - precision_1: 0.9332 - val_accuracy: 0.9031 - val_loss: 0.2649 - val_precision_1: 0.9059
# Epoch 8/10
# 530/530 ━━━━━━━━━━━━━━━━━━━━ 10s 15ms/step - accuracy: 0.9321 - loss: 0.1855 - precision_1: 0.9352 - val_accuracy: 0.9005 - val_loss: 0.2682 - val_precision_1: 0.9034
# Epoch 9/10
# 530/530 ━━━━━━━━━━━━━━━━━━━━ 8s 16ms/step - accuracy: 0.9322 - loss: 0.1835 - precision_1: 0.9346 - val_accuracy: 0.9064 - val_loss: 0.2729 - val_precision_1: 0.9092
# Epoch 10/10
# 530/530 ━━━━━━━━━━━━━━━━━━━━ 11s 17ms/step - accuracy: 0.9348 - loss: 0.1741 - precision_1: 0.9368 - val_accuracy: 0.9043 - val_loss: 0.2629 - val_precision_1: 0.9072

# %%
model.save('covid_cnn_model.keras')

# %%
#Save the Label encoder
import pickle

# Save the LabelEncoder object
label_encoder_filename = "label_encoder.pkl"
with open(label_encoder_filename, "wb") as file:
    pickle.dump(label_encoder, file)

# %%
from tqdm import tqdm
import numpy as np

# Predict on test data
predictions = model.predict(X_test, verbose=0)

# Get the predicted classes and true classes
predicted_classes = np.argmax(predictions, axis=1)
true_classes = np.argmax(y_test, axis=1)

# Calculate overall accuracy
overall_accuracy = np.sum(predicted_classes == true_classes) / len(true_classes)

# Print the overall test accuracy with the progress bar-like format
total_steps = len(X_test)  # Set total steps for progress bar
with tqdm(total=total_steps, desc="Evaluating", unit="file") as pbar:
    for i in range(len(X_test)):
        pbar.update(1)

# Print the overall accuracy in the same style as your example
print(f"Overall Test Accuracy: {overall_accuracy * 100:.2f}%")

# Decode class indices to labels
class_labels = label_encoder.inverse_transform(predicted_classes)
true_labels = label_encoder.inverse_transform(true_classes)

# Print accuracy for individual files
print("\nFile-level accuracy:")
for i in range(len(X_test)):
    print(f"File {i + 1}:")
    print(f"  Predicted Label: {class_labels[i]}")
    print(f"  True Label: {true_labels[i]}")
    print(f"  Correct: {class_labels[i] == true_labels[i]}")
    print("-" * 30)
# Out:
# Evaluating: 100%|██████████| 4233/4233 [00:00<00:00, 997331.13file/s]
# Streaming output truncated to the last 5000 lines.
# File 3234:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 3235:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 3236:
#   Predicted Label: Lung_Opacity
#   True Label: Lung_Opacity
#   Correct: True
# ------------------------------
# File 3237:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 3238:
#   Predicted Label: Lung_Opacity
#   True Label: Lung_Opacity
#   Correct: True
# ------------------------------
# File 3239:
#   Predicted Label: COVID
#   True Label: COVID
#   Correct: True
# ------------------------------
# File 3240:
#   Predicted Label: Lung_Opacity
#   True Label: Normal
#   Correct: False
# ------------------------------
# File 3241:
#   Predicted Label: Lung_Opacity
#   True Label: Lung_Opacity
#   Correct: True
# ------------------------------
# File 3242:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 3243:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 3244:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 3245:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 3246:
#   Predicted Label: Lung_Opacity
#   True Label: Lung_Opacity
#   Correct: True
# ------------------------------
# File 3247:
#   Predicted Label: COVID
#   True Label: COVID
#   Correct: True
# ------------------------------
# File 3248:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 3249:
#   Predicted Label: Normal
#   True Label: Lung_Opacity
#   Correct: False
# ------------------------------
# File 3250:
#   Predicted Label: Lung_Opacity
#   True Label: Lung_Opacity
#   Correct: True
# ------------------------------
# File 3251:
#   Predicted Label: Normal
#   True Label: Lung_Opacity
#   Correct: False
# ------------------------------
# File 3252:
#   Predicted Label: Lung_Opacity
#   True Label: Lung_Opacity
#   Correct: True
# ------------------------------
# File 3253:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 3254:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 3255:
#   Predicted Label: Lung_Opacity
#   True Label: Lung_Opacity
#   Correct: True
# ------------------------------
# File 3256:
#   Predicted Label: Lung_Opacity
#   True Label: Lung_Opacity
#   Correct: True
# ------------------------------
# File 3257:
#   Predicted Label: COVID
#   True Label: COVID
#   Correct: True
# ------------------------------
# File 3258:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 3259:
#   Predicted Label: Lung_Opacity
#   True Label: Lung_Opacity
#   Correct: True
# ------------------------------
# File 3260:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 3261:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 3262:
#   Predicted Label: Viral Pneumonia
#   True Label: Viral Pneumonia
#   Correct: True
# ------------------------------
# File 3263:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 3264:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 3265:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 3266:
#   Predicted Label: Lung_Opacity
#   True Label: Lung_Opacity
#   Correct: True
# ------------------------------
# File 3267:
#   Predicted Label: COVID
#   True Label: Normal
#   Correct: False
# ------------------------------
# File 3268:
#   Predicted Label: Lung_Opacity
#   True Label: Lung_Opacity
#   Correct: True
# ------------------------------
# File 3269:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 3270:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 3271:
#   Predicted Label: Lung_Opacity
#   True Label: Lung_Opacity
#   Correct: True
# ------------------------------
# File 3272:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 3273:
#   Predicted Label: Lung_Opacity
#   True Label: Lung_Opacity
#   Correct: True
# ------------------------------
# File 3274:
#   Predicted Label: COVID
#   True Label: COVID
#   Correct: True
# ------------------------------
# File 3275:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 3276:
#   Predicted Label: Viral Pneumonia
#   True Label: Viral Pneumonia
#   Correct: True
# ------------------------------
# File 3277:
#   Predicted Label: Viral Pneumonia
#   True Label: Viral Pneumonia
#   Correct: True
# ------------------------------
# File 3278:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 3279:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 3280:
#   Predicted Label: COVID
#   True Label: COVID
#   Correct: True
# ------------------------------
# File 3281:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 3282:
#   Predicted Label: Lung_Opacity
#   True Label: Normal
#   Correct: False
# ------------------------------
# File 3283:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 3284:
#   Predicted Label: Viral Pneumonia
#   True Label: Viral Pneumonia
#   Correct: True
# ------------------------------
# File 3285:
#   Predicted Label: Normal
#   True Label: Lung_Opacity
#   Correct: False
# ------------------------------
# File 3286:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 3287:
#   Predicted Label: COVID
#   True Label: COVID
#   Correct: True
# ------------------------------
# File 3288:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 3289:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 3290:
#   Predicted Label: Viral Pneumonia
#   True Label: Viral Pneumonia
#   Correct: True
# ------------------------------
# File 3291:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 3292:
#   Predicted Label: Lung_Opacity
#   True Label: Lung_Opacity
#   Correct: True
# ------------------------------
# File 3293:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 3294:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 3295:
#   Predicted Label: Lung_Opacity
#   True Label: Lung_Opacity
#   Correct: True
# ------------------------------
# File 3296:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 3297:
#   Predicted Label: COVID
#   True Label: COVID
#   Correct: True
# ------------------------------
# File 3298:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 3299:
#   Predicted Label: COVID
#   True Label: COVID
#   Correct: True
# ------------------------------
# File 3300:
#   Predicted Label: Lung_Opacity
#   True Label: Lung_Opacity
#   Correct: True
# ------------------------------
# File 3301:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 3302:
#   Predicted Label: Lung_Opacity
#   True Label: Lung_Opacity
#   Correct: True
# ------------------------------
# File 3303:
#   Predicted Label: Lung_Opacity
#   True Label: COVID
#   Correct: False
# ------------------------------
# File 3304:
#   Predicted Label: COVID
#   True Label: COVID
#   Correct: True
# ------------------------------
# File 3305:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 3306:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 3307:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 3308:
#   Predicted Label: Viral Pneumonia
#   True Label: Viral Pneumonia
#   Correct: True
# ------------------------------
# File 3309:
#   Predicted Label: Lung_Opacity
#   True Label: Lung_Opacity
#   Correct: True
# ------------------------------
# File 3310:
#   Predicted Label: Lung_Opacity
#   True Label: Normal
#   Correct: False
# ------------------------------
# File 3311:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 3312:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 3313:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 3314:
#   Predicted Label: Lung_Opacity
#   True Label: Lung_Opacity
#   Correct: True
# ------------------------------
# File 3315:
#   Predicted Label: Normal
#   True Label: Lung_Opacity
#   Correct: False
# ------------------------------
# File 3316:
#   Predicted Label: Normal
#   True Label: Lung_Opacity
#   Correct: False
# ------------------------------
# File 3317:
#   Predicted Label: Lung_Opacity
#   True Label: Lung_Opacity
#   Correct: True
# ------------------------------
# File 3318:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 3319:
#   Predicted Label: Lung_Opacity
#   True Label: Lung_Opacity
#   Correct: True
# ------------------------------
# File 3320:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 3321:
#   Predicted Label: Normal
#   True Label: Lung_Opacity
#   Correct: False
# ------------------------------
# File 3322:
#   Predicted Label: Lung_Opacity
#   True Label: Lung_Opacity
#   Correct: True
# ------------------------------
# File 3323:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 3324:
#   Predicted Label: Lung_Opacity
#   True Label: Normal
#   Correct: False
# ------------------------------
# File 3325:
#   Predicted Label: Lung_Opacity
#   True Label: Lung_Opacity
#   Correct: True
# ------------------------------
# File 3326:
#   Predicted Label: Lung_Opacity
#   True Label: Lung_Opacity
#   Correct: True
# ------------------------------
# File 3327:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 3328:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 3329:
#   Predicted Label: Lung_Opacity
#   True Label: Lung_Opacity
#   Correct: True
# ------------------------------
# File 3330:
#   Predicted Label: Viral Pneumonia
#   True Label: Viral Pneumonia
#   Correct: True
# ------------------------------
# File 3331:
#   Predicted Label: Lung_Opacity
#   True Label: Lung_Opacity
#   Correct: True
# ------------------------------
# File 3332:
#   Predicted Label: Lung_Opacity
#   True Label: Lung_Opacity
#   Correct: True
# ------------------------------
# File 3333:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 3334:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 3335:
#   Predicted Label: COVID
#   True Label: COVID
#   Correct: True
# ------------------------------
# File 3336:
#   Predicted Label: COVID
#   True Label: COVID
#   Correct: True
# ------------------------------
# File 3337:
#   Predicted Label: Lung_Opacity
#   True Label: Lung_Opacity
#   Correct: True
# ------------------------------
# File 3338:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 3339:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 3340:
#   Predicted Label: Normal
#   True Label: Lung_Opacity
#   Correct: False
# ------------------------------
# File 3341:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 3342:
#   Predicted Label: Normal
#   True Label: Lung_Opacity
#   Correct: False
# ------------------------------
# File 3343:
#   Predicted Label: COVID
#   True Label: Lung_Opacity
#   Correct: False
# ------------------------------
# File 3344:
#   Predicted Label: COVID
#   True Label: Normal
#   Correct: False
# ------------------------------
# File 3345:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 3346:
#   Predicted Label: COVID
#   True Label: COVID
#   Correct: True
# ------------------------------
# File 3347:
#   Predicted Label: COVID
#   True Label: Lung_Opacity
#   Correct: False
# ------------------------------
# File 3348:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 3349:
#   Predicted Label: Lung_Opacity
#   True Label: Lung_Opacity
#   Correct: True
# ------------------------------
# File 3350:
#   Predicted Label: Normal
#   True Label: Lung_Opacity
#   Correct: False
# ------------------------------
# File 3351:
#   Predicted Label: Lung_Opacity
#   True Label: Lung_Opacity
#   Correct: True
# ------------------------------
# File 3352:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 3353:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 3354:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 3355:
#   Predicted Label: Lung_Opacity
#   True Label: Lung_Opacity
#   Correct: True
# ------------------------------
# File 3356:
#   Predicted Label: Lung_Opacity
#   True Label: Lung_Opacity
#   Correct: True
# ------------------------------
# File 3357:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 3358:
#   Predicted Label: Lung_Opacity
#   True Label: Lung_Opacity
#   Correct: True
# ------------------------------
# File 3359:
#   Predicted Label: Lung_Opacity
#   True Label: Lung_Opacity
#   Correct: True
# ------------------------------
# File 3360:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 3361:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 3362:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 3363:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 3364:
#   Predicted Label: Lung_Opacity
#   True Label: Lung_Opacity
#   Correct: True
# ------------------------------
# File 3365:
#   Predicted Label: Lung_Opacity
#   True Label: Lung_Opacity
#   Correct: True
# ------------------------------
# File 3366:
#   Predicted Label: Viral Pneumonia
#   True Label: Viral Pneumonia
#   Correct: True
# ------------------------------
# File 3367:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 3368:
#   Predicted Label: COVID
#   True Label: Normal
#   Correct: False
# ------------------------------
# File 3369:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 3370:
#   Predicted Label: COVID
#   True Label: COVID
#   Correct: True
# ------------------------------
# File 3371:
#   Predicted Label: Lung_Opacity
#   True Label: Lung_Opacity
#   Correct: True
# ------------------------------
# File 3372:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 3373:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 3374:
#   Predicted Label: Lung_Opacity
#   True Label: Lung_Opacity
#   Correct: True
# ------------------------------
# File 3375:
#   Predicted Label: Lung_Opacity
#   True Label: COVID
#   Correct: False
# ------------------------------
# File 3376:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 3377:
#   Predicted Label: Viral Pneumonia
#   True Label: Viral Pneumonia
#   Correct: True
# ------------------------------
# File 3378:
#   Predicted Label: Viral Pneumonia
#   True Label: Viral Pneumonia
#   Correct: True
# ------------------------------
# File 3379:
#   Predicted Label: Lung_Opacity
#   True Label: Lung_Opacity
#   Correct: True
# ------------------------------
# File 3380:
#   Predicted Label: Lung_Opacity
#   True Label: Lung_Opacity
#   Correct: True
# ------------------------------
# File 3381:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 3382:
#   Predicted Label: Lung_Opacity
#   True Label: Lung_Opacity
#   Correct: True
# ------------------------------
# File 3383:
#   Predicted Label: COVID
#   True Label: Normal
#   Correct: False
# ------------------------------
# File 3384:
#   Predicted Label: Normal
#   True Label: Lung_Opacity
#   Correct: False
# ------------------------------
# File 3385:
#   Predicted Label: Lung_Opacity
#   True Label: Lung_Opacity
#   Correct: True
# ------------------------------
# File 3386:
#   Predicted Label: COVID
#   True Label: Normal
#   Correct: False
# ------------------------------
# File 3387:
#   Predicted Label: Lung_Opacity
#   True Label: Lung_Opacity
#   Correct: True
# ------------------------------
# File 3388:
#   Predicted Label: Lung_Opacity
#   True Label: Lung_Opacity
#   Correct: True
# ------------------------------
# File 3389:
#   Predicted Label: Lung_Opacity
#   True Label: Lung_Opacity
#   Correct: True
# ------------------------------
# File 3390:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 3391:
#   Predicted Label: Lung_Opacity
#   True Label: Lung_Opacity
#   Correct: True
# ------------------------------
# File 3392:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 3393:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 3394:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 3395:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 3396:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 3397:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 3398:
#   Predicted Label: COVID
#   True Label: COVID
#   Correct: True
# ------------------------------
# File 3399:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 3400:
#   Predicted Label: Viral Pneumonia
#   True Label: COVID
#   Correct: False
# ------------------------------
# File 3401:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 3402:
#   Predicted Label: Normal
#   True Label: Lung_Opacity
#   Correct: False
# ------------------------------
# File 3403:
#   Predicted Label: Normal
#   True Label: Lung_Opacity
#   Correct: False
# ------------------------------
# File 3404:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 3405:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 3406:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 3407:
#   Predicted Label: Lung_Opacity
#   True Label: Lung_Opacity
#   Correct: True
# ------------------------------
# File 3408:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 3409:
#   Predicted Label: Normal
#   True Label: Lung_Opacity
#   Correct: False
# ------------------------------
# File 3410:
#   Predicted Label: Lung_Opacity
#   True Label: Lung_Opacity
#   Correct: True
# ------------------------------
# File 3411:
#   Predicted Label: Viral Pneumonia
#   True Label: Viral Pneumonia
#   Correct: True
# ------------------------------
# File 3412:
#   Predicted Label: Lung_Opacity
#   True Label: Normal
#   Correct: False
# ------------------------------
# File 3413:
#   Predicted Label: COVID
#   True Label: COVID
#   Correct: True
# ------------------------------
# File 3414:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 3415:
#   Predicted Label: Lung_Opacity
#   True Label: Lung_Opacity
#   Correct: True
# ------------------------------
# File 3416:
#   Predicted Label: Normal
#   True Label: Lung_Opacity
#   Correct: False
# ------------------------------
# File 3417:
#   Predicted Label: Lung_Opacity
#   True Label: Lung_Opacity
#   Correct: True
# ------------------------------
# File 3418:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 3419:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 3420:
#   Predicted Label: Normal
#   True Label: Lung_Opacity
#   Correct: False
# ------------------------------
# File 3421:
#   Predicted Label: Normal
#   True Label: Lung_Opacity
#   Correct: False
# ------------------------------
# File 3422:
#   Predicted Label: COVID
#   True Label: COVID
#   Correct: True
# ------------------------------
# File 3423:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 3424:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 3425:
#   Predicted Label: COVID
#   True Label: COVID
#   Correct: True
# ------------------------------
# File 3426:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 3427:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 3428:
#   Predicted Label: Lung_Opacity
#   True Label: Lung_Opacity
#   Correct: True
# ------------------------------
# File 3429:
#   Predicted Label: Lung_Opacity
#   True Label: Lung_Opacity
#   Correct: True
# ------------------------------
# File 3430:
#   Predicted Label: Lung_Opacity
#   True Label: Lung_Opacity
#   Correct: True
# ------------------------------
# File 3431:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 3432:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 3433:
#   Predicted Label: Lung_Opacity
#   True Label: Lung_Opacity
#   Correct: True
# ------------------------------
# File 3434:
#   Predicted Label: Lung_Opacity
#   True Label: Lung_Opacity
#   Correct: True
# ------------------------------
# File 3435:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 3436:
#   Predicted Label: Lung_Opacity
#   True Label: Lung_Opacity
#   Correct: True
# ------------------------------
# File 3437:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 3438:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 3439:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 3440:
#   Predicted Label: Lung_Opacity
#   True Label: Lung_Opacity
#   Correct: True
# ------------------------------
# File 3441:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 3442:
#   Predicted Label: Lung_Opacity
#   True Label: Lung_Opacity
#   Correct: True
# ------------------------------
# File 3443:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 3444:
#   Predicted Label: Lung_Opacity
#   True Label: Lung_Opacity
#   Correct: True
# ------------------------------
# File 3445:
#   Predicted Label: COVID
#   True Label: COVID
#   Correct: True
# ------------------------------
# File 3446:
#   Predicted Label: COVID
#   True Label: COVID
#   Correct: True
# ------------------------------
# File 3447:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 3448:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 3449:
#   Predicted Label: Lung_Opacity
#   True Label: Lung_Opacity
#   Correct: True
# ------------------------------
# File 3450:
#   Predicted Label: Lung_Opacity
#   True Label: Normal
#   Correct: False
# ------------------------------
# File 3451:
#   Predicted Label: Viral Pneumonia
#   True Label: Viral Pneumonia
#   Correct: True
# ------------------------------
# File 3452:
#   Predicted Label: Lung_Opacity
#   True Label: Lung_Opacity
#   Correct: True
# ------------------------------
# File 3453:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 3454:
#   Predicted Label: Lung_Opacity
#   True Label: Lung_Opacity
#   Correct: True
# ------------------------------
# File 3455:
#   Predicted Label: Lung_Opacity
#   True Label: Lung_Opacity
#   Correct: True
# ------------------------------
# File 3456:
#   Predicted Label: Lung_Opacity
#   True Label: Lung_Opacity
#   Correct: True
# ------------------------------
# File 3457:
#   Predicted Label: Lung_Opacity
#   True Label: Normal
#   Correct: False
# ------------------------------
# File 3458:
#   Predicted Label: Viral Pneumonia
#   True Label: Viral Pneumonia
#   Correct: True
# ------------------------------
# File 3459:
#   Predicted Label: COVID
#   True Label: COVID
#   Correct: True
# ------------------------------
# File 3460:
#   Predicted Label: Lung_Opacity
#   True Label: Lung_Opacity
#   Correct: True
# ------------------------------
# File 3461:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 3462:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 3463:
#   Predicted Label: COVID
#   True Label: Normal
#   Correct: False
# ------------------------------
# File 3464:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 3465:
#   Predicted Label: Lung_Opacity
#   True Label: Lung_Opacity
#   Correct: True
# ------------------------------
# File 3466:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 3467:
#   Predicted Label: COVID
#   True Label: COVID
#   Correct: True
# ------------------------------
# File 3468:
#   Predicted Label: Lung_Opacity
#   True Label: Lung_Opacity
#   Correct: True
# ------------------------------
# File 3469:
#   Predicted Label: Lung_Opacity
#   True Label: Lung_Opacity
#   Correct: True
# ------------------------------
# File 3470:
#   Predicted Label: COVID
#   True Label: COVID
#   Correct: True
# ------------------------------
# File 3471:
#   Predicted Label: COVID
#   True Label: Normal
#   Correct: False
# ------------------------------
# File 3472:
#   Predicted Label: Lung_Opacity
#   True Label: Lung_Opacity
#   Correct: True
# ------------------------------
# File 3473:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 3474:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 3475:
#   Predicted Label: Lung_Opacity
#   True Label: Lung_Opacity
#   Correct: True
# ------------------------------
# File 3476:
#   Predicted Label: Lung_Opacity
#   True Label: Lung_Opacity
#   Correct: True
# ------------------------------
# File 3477:
#   Predicted Label: Lung_Opacity
#   True Label: Lung_Opacity
#   Correct: True
# ------------------------------
# File 3478:
#   Predicted Label: Lung_Opacity
#   True Label: Lung_Opacity
#   Correct: True
# ------------------------------
# File 3479:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 3480:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 3481:
#   Predicted Label: Viral Pneumonia
#   True Label: Viral Pneumonia
#   Correct: True
# ------------------------------
# File 3482:
#   Predicted Label: COVID
#   True Label: COVID
#   Correct: True
# ------------------------------
# File 3483:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 3484:
#   Predicted Label: Lung_Opacity
#   True Label: Lung_Opacity
#   Correct: True
# ------------------------------
# File 3485:
#   Predicted Label: COVID
#   True Label: COVID
#   Correct: True
# ------------------------------
# File 3486:
#   Predicted Label: Lung_Opacity
#   True Label: Lung_Opacity
#   Correct: True
# ------------------------------
# File 3487:
#   Predicted Label: Normal
#   True Label: Lung_Opacity
#   Correct: False
# ------------------------------
# File 3488:
#   Predicted Label: Lung_Opacity
#   True Label: Lung_Opacity
#   Correct: True
# ------------------------------
# File 3489:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 3490:
#   Predicted Label: COVID
#   True Label: COVID
#   Correct: True
# ------------------------------
# File 3491:
#   Predicted Label: COVID
#   True Label: COVID
#   Correct: True
# ------------------------------
# File 3492:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 3493:
#   Predicted Label: Normal
#   True Label: Lung_Opacity
#   Correct: False
# ------------------------------
# File 3494:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 3495:
#   Predicted Label: Lung_Opacity
#   True Label: Lung_Opacity
#   Correct: True
# ------------------------------
# File 3496:
#   Predicted Label: COVID
#   True Label: COVID
#   Correct: True
# ------------------------------
# File 3497:
#   Predicted Label: Lung_Opacity
#   True Label: Lung_Opacity
#   Correct: True
# ------------------------------
# File 3498:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 3499:
#   Predicted Label: Lung_Opacity
#   True Label: Lung_Opacity
#   Correct: True
# ------------------------------
# File 3500:
#   Predicted Label: Lung_Opacity
#   True Label: Lung_Opacity
#   Correct: True
# ------------------------------
# File 3501:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 3502:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 3503:
#   Predicted Label: Lung_Opacity
#   True Label: Lung_Opacity
#   Correct: True
# ------------------------------
# File 3504:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 3505:
#   Predicted Label: Normal
#   True Label: Lung_Opacity
#   Correct: False
# ------------------------------
# File 3506:
#   Predicted Label: Lung_Opacity
#   True Label: Lung_Opacity
#   Correct: True
# ------------------------------
# File 3507:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 3508:
#   Predicted Label: COVID
#   True Label: COVID
#   Correct: True
# ------------------------------
# File 3509:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 3510:
#   Predicted Label: COVID
#   True Label: Lung_Opacity
#   Correct: False
# ------------------------------
# File 3511:
#   Predicted Label: Lung_Opacity
#   True Label: Lung_Opacity
#   Correct: True
# ------------------------------
# File 3512:
#   Predicted Label: Lung_Opacity
#   True Label: Lung_Opacity
#   Correct: True
# ------------------------------
# File 3513:
#   Predicted Label: Lung_Opacity
#   True Label: Lung_Opacity
#   Correct: True
# ------------------------------
# File 3514:
#   Predicted Label: Lung_Opacity
#   True Label: Lung_Opacity
#   Correct: True
# ------------------------------
# File 3515:
#   Predicted Label: COVID
#   True Label: COVID
#   Correct: True
# ------------------------------
# File 3516:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 3517:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 3518:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 3519:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 3520:
#   Predicted Label: Lung_Opacity
#   True Label: Lung_Opacity
#   Correct: True
# ------------------------------
# File 3521:
#   Predicted Label: Lung_Opacity
#   True Label: Lung_Opacity
#   Correct: True
# ------------------------------
# File 3522:
#   Predicted Label: Normal
#   True Label: Lung_Opacity
#   Correct: False
# ------------------------------
# File 3523:
#   Predicted Label: COVID
#   True Label: COVID
#   Correct: True
# ------------------------------
# File 3524:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 3525:
#   Predicted Label: Lung_Opacity
#   True Label: Lung_Opacity
#   Correct: True
# ------------------------------
# File 3526:
#   Predicted Label: Viral Pneumonia
#   True Label: Viral Pneumonia
#   Correct: True
# ------------------------------
# File 3527:
#   Predicted Label: Lung_Opacity
#   True Label: Lung_Opacity
#   Correct: True
# ------------------------------
# File 3528:
#   Predicted Label: Viral Pneumonia
#   True Label: Viral Pneumonia
#   Correct: True
# ------------------------------
# File 3529:
#   Predicted Label: COVID
#   True Label: COVID
#   Correct: True
# ------------------------------
# File 3530:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 3531:
#   Predicted Label: Viral Pneumonia
#   True Label: Viral Pneumonia
#   Correct: True
# ------------------------------
# File 3532:
#   Predicted Label: Viral Pneumonia
#   True Label: Viral Pneumonia
#   Correct: True
# ------------------------------
# File 3533:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 3534:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 3535:
#   Predicted Label: COVID
#   True Label: COVID
#   Correct: True
# ------------------------------
# File 3536:
#   Predicted Label: Lung_Opacity
#   True Label: Normal
#   Correct: False
# ------------------------------
# File 3537:
#   Predicted Label: Lung_Opacity
#   True Label: Lung_Opacity
#   Correct: True
# ------------------------------
# File 3538:
#   Predicted Label: Lung_Opacity
#   True Label: Lung_Opacity
#   Correct: True
# ------------------------------
# File 3539:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 3540:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 3541:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 3542:
#   Predicted Label: Lung_Opacity
#   True Label: Lung_Opacity
#   Correct: True
# ------------------------------
# File 3543:
#   Predicted Label: Lung_Opacity
#   True Label: Normal
#   Correct: False
# ------------------------------
# File 3544:
#   Predicted Label: Normal
#   True Label: Lung_Opacity
#   Correct: False
# ------------------------------
# File 3545:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 3546:
#   Predicted Label: Viral Pneumonia
#   True Label: Viral Pneumonia
#   Correct: True
# ------------------------------
# File 3547:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 3548:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 3549:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 3550:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 3551:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 3552:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 3553:
#   Predicted Label: Lung_Opacity
#   True Label: Lung_Opacity
#   Correct: True
# ------------------------------
# File 3554:
#   Predicted Label: Lung_Opacity
#   True Label: Lung_Opacity
#   Correct: True
# ------------------------------
# File 3555:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 3556:
#   Predicted Label: Viral Pneumonia
#   True Label: COVID
#   Correct: False
# ------------------------------
# File 3557:
#   Predicted Label: COVID
#   True Label: COVID
#   Correct: True
# ------------------------------
# File 3558:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 3559:
#   Predicted Label: Lung_Opacity
#   True Label: Lung_Opacity
#   Correct: True
# ------------------------------
# File 3560:
#   Predicted Label: Lung_Opacity
#   True Label: Lung_Opacity
#   Correct: True
# ------------------------------
# File 3561:
#   Predicted Label: Lung_Opacity
#   True Label: Lung_Opacity
#   Correct: True
# ------------------------------
# File 3562:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 3563:
#   Predicted Label: COVID
#   True Label: COVID
#   Correct: True
# ------------------------------
# File 3564:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 3565:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 3566:
#   Predicted Label: Viral Pneumonia
#   True Label: Viral Pneumonia
#   Correct: True
# ------------------------------
# File 3567:
#   Predicted Label: Lung_Opacity
#   True Label: Lung_Opacity
#   Correct: True
# ------------------------------
# File 3568:
#   Predicted Label: COVID
#   True Label: COVID
#   Correct: True
# ------------------------------
# File 3569:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 3570:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 3571:
#   Predicted Label: COVID
#   True Label: COVID
#   Correct: True
# ------------------------------
# File 3572:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 3573:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 3574:
#   Predicted Label: COVID
#   True Label: COVID
#   Correct: True
# ------------------------------
# File 3575:
#   Predicted Label: COVID
#   True Label: COVID
#   Correct: True
# ------------------------------
# File 3576:
#   Predicted Label: Lung_Opacity
#   True Label: Lung_Opacity
#   Correct: True
# ------------------------------
# File 3577:
#   Predicted Label: Lung_Opacity
#   True Label: Lung_Opacity
#   Correct: True
# ------------------------------
# File 3578:
#   Predicted Label: COVID
#   True Label: COVID
#   Correct: True
# ------------------------------
# File 3579:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 3580:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 3581:
#   Predicted Label: Lung_Opacity
#   True Label: Lung_Opacity
#   Correct: True
# ------------------------------
# File 3582:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 3583:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 3584:
#   Predicted Label: Lung_Opacity
#   True Label: Lung_Opacity
#   Correct: True
# ------------------------------
# File 3585:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 3586:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 3587:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 3588:
#   Predicted Label: COVID
#   True Label: COVID
#   Correct: True
# ------------------------------
# File 3589:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 3590:
#   Predicted Label: Lung_Opacity
#   True Label: Normal
#   Correct: False
# ------------------------------
# File 3591:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 3592:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 3593:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 3594:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 3595:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 3596:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 3597:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 3598:
#   Predicted Label: Lung_Opacity
#   True Label: Lung_Opacity
#   Correct: True
# ------------------------------
# File 3599:
#   Predicted Label: Lung_Opacity
#   True Label: Lung_Opacity
#   Correct: True
# ------------------------------
# File 3600:
#   Predicted Label: COVID
#   True Label: COVID
#   Correct: True
# ------------------------------
# File 3601:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 3602:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 3603:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 3604:
#   Predicted Label: Lung_Opacity
#   True Label: Lung_Opacity
#   Correct: True
# ------------------------------
# File 3605:
#   Predicted Label: Lung_Opacity
#   True Label: Lung_Opacity
#   Correct: True
# ------------------------------
# File 3606:
#   Predicted Label: Lung_Opacity
#   True Label: Lung_Opacity
#   Correct: True
# ------------------------------
# File 3607:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 3608:
#   Predicted Label: Viral Pneumonia
#   True Label: Viral Pneumonia
#   Correct: True
# ------------------------------
# File 3609:
#   Predicted Label: COVID
#   True Label: COVID
#   Correct: True
# ------------------------------
# File 3610:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 3611:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 3612:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 3613:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 3614:
#   Predicted Label: Lung_Opacity
#   True Label: Lung_Opacity
#   Correct: True
# ------------------------------
# File 3615:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 3616:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 3617:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 3618:
#   Predicted Label: Lung_Opacity
#   True Label: Lung_Opacity
#   Correct: True
# ------------------------------
# File 3619:
#   Predicted Label: Lung_Opacity
#   True Label: Lung_Opacity
#   Correct: True
# ------------------------------
# File 3620:
#   Predicted Label: Viral Pneumonia
#   True Label: Viral Pneumonia
#   Correct: True
# ------------------------------
# File 3621:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 3622:
#   Predicted Label: Lung_Opacity
#   True Label: Lung_Opacity
#   Correct: True
# ------------------------------
# File 3623:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 3624:
#   Predicted Label: Lung_Opacity
#   True Label: Lung_Opacity
#   Correct: True
# ------------------------------
# File 3625:
#   Predicted Label: Normal
#   True Label: Lung_Opacity
#   Correct: False
# ------------------------------
# File 3626:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 3627:
#   Predicted Label: COVID
#   True Label: COVID
#   Correct: True
# ------------------------------
# File 3628:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 3629:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 3630:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 3631:
#   Predicted Label: COVID
#   True Label: COVID
#   Correct: True
# ------------------------------
# File 3632:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 3633:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 3634:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 3635:
#   Predicted Label: Lung_Opacity
#   True Label: Lung_Opacity
#   Correct: True
# ------------------------------
# File 3636:
#   Predicted Label: COVID
#   True Label: COVID
#   Correct: True
# ------------------------------
# File 3637:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 3638:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 3639:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 3640:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 3641:
#   Predicted Label: Lung_Opacity
#   True Label: Normal
#   Correct: False
# ------------------------------
# File 3642:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 3643:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 3644:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 3645:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 3646:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 3647:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 3648:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 3649:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 3650:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 3651:
#   Predicted Label: Normal
#   True Label: Lung_Opacity
#   Correct: False
# ------------------------------
# File 3652:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 3653:
#   Predicted Label: Lung_Opacity
#   True Label: Lung_Opacity
#   Correct: True
# ------------------------------
# File 3654:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 3655:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 3656:
#   Predicted Label: COVID
#   True Label: COVID
#   Correct: True
# ------------------------------
# File 3657:
#   Predicted Label: Lung_Opacity
#   True Label: Lung_Opacity
#   Correct: True
# ------------------------------
# File 3658:
#   Predicted Label: Lung_Opacity
#   True Label: Lung_Opacity
#   Correct: True
# ------------------------------
# File 3659:
#   Predicted Label: Viral Pneumonia
#   True Label: Viral Pneumonia
#   Correct: True
# ------------------------------
# File 3660:
#   Predicted Label: COVID
#   True Label: COVID
#   Correct: True
# ------------------------------
# File 3661:
#   Predicted Label: Lung_Opacity
#   True Label: Lung_Opacity
#   Correct: True
# ------------------------------
# File 3662:
#   Predicted Label: Lung_Opacity
#   True Label: Lung_Opacity
#   Correct: True
# ------------------------------
# File 3663:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 3664:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 3665:
#   Predicted Label: Lung_Opacity
#   True Label: Lung_Opacity
#   Correct: True
# ------------------------------
# File 3666:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 3667:
#   Predicted Label: Lung_Opacity
#   True Label: Lung_Opacity
#   Correct: True
# ------------------------------
# File 3668:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 3669:
#   Predicted Label: COVID
#   True Label: COVID
#   Correct: True
# ------------------------------
# File 3670:
#   Predicted Label: Normal
# ...
#   Correct: True
# ------------------------------
# File 4086:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 4087:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 4088:
#   Predicted Label: Lung_Opacity
#   True Label: Lung_Opacity
#   Correct: True
# ------------------------------
# File 4089:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 4090:
#   Predicted Label: COVID
#   True Label: COVID
#   Correct: True
# ------------------------------
# File 4091:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 4092:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 4093:
#   Predicted Label: Lung_Opacity
#   True Label: Lung_Opacity
#   Correct: True
# ------------------------------
# File 4094:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 4095:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 4096:
#   Predicted Label: Lung_Opacity
#   True Label: Lung_Opacity
#   Correct: True
# ------------------------------
# File 4097:
#   Predicted Label: COVID
#   True Label: COVID
#   Correct: True
# ------------------------------
# File 4098:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 4099:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 4100:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 4101:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 4102:
#   Predicted Label: COVID
#   True Label: COVID
#   Correct: True
# ------------------------------
# File 4103:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 4104:
#   Predicted Label: Viral Pneumonia
#   True Label: Viral Pneumonia
#   Correct: True
# ------------------------------
# File 4105:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 4106:
#   Predicted Label: Lung_Opacity
#   True Label: Lung_Opacity
#   Correct: True
# ------------------------------
# File 4107:
#   Predicted Label: Lung_Opacity
#   True Label: Lung_Opacity
#   Correct: True
# ------------------------------
# File 4108:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 4109:
#   Predicted Label: COVID
#   True Label: COVID
#   Correct: True
# ------------------------------
# File 4110:
#   Predicted Label: Lung_Opacity
#   True Label: Lung_Opacity
#   Correct: True
# ------------------------------
# File 4111:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 4112:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 4113:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 4114:
#   Predicted Label: COVID
#   True Label: COVID
#   Correct: True
# ------------------------------
# File 4115:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 4116:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 4117:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 4118:
#   Predicted Label: Lung_Opacity
#   True Label: Lung_Opacity
#   Correct: True
# ------------------------------
# File 4119:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 4120:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 4121:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 4122:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 4123:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 4124:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 4125:
#   Predicted Label: Viral Pneumonia
#   True Label: Viral Pneumonia
#   Correct: True
# ------------------------------
# File 4126:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 4127:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 4128:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 4129:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 4130:
#   Predicted Label: Lung_Opacity
#   True Label: Lung_Opacity
#   Correct: True
# ------------------------------
# File 4131:
#   Predicted Label: Lung_Opacity
#   True Label: Lung_Opacity
#   Correct: True
# ------------------------------
# File 4132:
#   Predicted Label: Normal
#   True Label: Lung_Opacity
#   Correct: False
# ------------------------------
# File 4133:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 4134:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 4135:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 4136:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 4137:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 4138:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 4139:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 4140:
#   Predicted Label: Lung_Opacity
#   True Label: Lung_Opacity
#   Correct: True
# ------------------------------
# File 4141:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 4142:
#   Predicted Label: COVID
#   True Label: COVID
#   Correct: True
# ------------------------------
# File 4143:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 4144:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 4145:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 4146:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 4147:
#   Predicted Label: COVID
#   True Label: COVID
#   Correct: True
# ------------------------------
# File 4148:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 4149:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 4150:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 4151:
#   Predicted Label: Lung_Opacity
#   True Label: Lung_Opacity
#   Correct: True
# ------------------------------
# File 4152:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 4153:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 4154:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 4155:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 4156:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 4157:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 4158:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 4159:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 4160:
#   Predicted Label: Lung_Opacity
#   True Label: Lung_Opacity
#   Correct: True
# ------------------------------
# File 4161:
#   Predicted Label: Lung_Opacity
#   True Label: Lung_Opacity
#   Correct: True
# ------------------------------
# File 4162:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 4163:
#   Predicted Label: COVID
#   True Label: COVID
#   Correct: True
# ------------------------------
# File 4164:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 4165:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 4166:
#   Predicted Label: COVID
#   True Label: COVID
#   Correct: True
# ------------------------------
# File 4167:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 4168:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 4169:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 4170:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 4171:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 4172:
#   Predicted Label: Lung_Opacity
#   True Label: Lung_Opacity
#   Correct: True
# ------------------------------
# File 4173:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 4174:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 4175:
#   Predicted Label: Lung_Opacity
#   True Label: Lung_Opacity
#   Correct: True
# ------------------------------
# File 4176:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 4177:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 4178:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 4179:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 4180:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 4181:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 4182:
#   Predicted Label: COVID
#   True Label: COVID
#   Correct: True
# ------------------------------
# File 4183:
#   Predicted Label: Lung_Opacity
#   True Label: Lung_Opacity
#   Correct: True
# ------------------------------
# File 4184:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 4185:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 4186:
#   Predicted Label: Lung_Opacity
#   True Label: Lung_Opacity
#   Correct: True
# ------------------------------
# File 4187:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 4188:
#   Predicted Label: Viral Pneumonia
#   True Label: Viral Pneumonia
#   Correct: True
# ------------------------------
# File 4189:
#   Predicted Label: COVID
#   True Label: COVID
#   Correct: True
# ------------------------------
# File 4190:
#   Predicted Label: COVID
#   True Label: COVID
#   Correct: True
# ------------------------------
# File 4191:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 4192:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 4193:
#   Predicted Label: Lung_Opacity
#   True Label: Lung_Opacity
#   Correct: True
# ------------------------------
# File 4194:
#   Predicted Label: COVID
#   True Label: COVID
#   Correct: True
# ------------------------------
# File 4195:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 4196:
#   Predicted Label: COVID
#   True Label: COVID
#   Correct: True
# ------------------------------
# File 4197:
#   Predicted Label: Lung_Opacity
#   True Label: Lung_Opacity
#   Correct: True
# ------------------------------
# File 4198:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 4199:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 4200:
#   Predicted Label: Lung_Opacity
#   True Label: Normal
#   Correct: False
# ------------------------------
# File 4201:
#   Predicted Label: COVID
#   True Label: COVID
#   Correct: True
# ------------------------------
# File 4202:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 4203:
#   Predicted Label: Lung_Opacity
#   True Label: Lung_Opacity
#   Correct: True
# ------------------------------
# File 4204:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 4205:
#   Predicted Label: COVID
#   True Label: COVID
#   Correct: True
# ------------------------------
# File 4206:
#   Predicted Label: COVID
#   True Label: COVID
#   Correct: True
# ------------------------------
# File 4207:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 4208:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 4209:
#   Predicted Label: Lung_Opacity
#   True Label: Lung_Opacity
#   Correct: True
# ------------------------------
# File 4210:
#   Predicted Label: Normal
#   True Label: Lung_Opacity
#   Correct: False
# ------------------------------
# File 4211:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 4212:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 4213:
#   Predicted Label: Lung_Opacity
#   True Label: Lung_Opacity
#   Correct: True
# ------------------------------
# File 4214:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 4215:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 4216:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 4217:
#   Predicted Label: Lung_Opacity
#   True Label: Lung_Opacity
#   Correct: True
# ------------------------------
# File 4218:
#   Predicted Label: Lung_Opacity
#   True Label: Lung_Opacity
#   Correct: True
# ------------------------------
# File 4219:
#   Predicted Label: Lung_Opacity
#   True Label: Lung_Opacity
#   Correct: True
# ------------------------------
# File 4220:
#   Predicted Label: Lung_Opacity
#   True Label: Lung_Opacity
#   Correct: True
# ------------------------------
# File 4221:
#   Predicted Label: COVID
#   True Label: COVID
#   Correct: True
# ------------------------------
# File 4222:
#   Predicted Label: Normal
#   True Label: Lung_Opacity
#   Correct: False
# ------------------------------
# File 4223:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 4224:
#   Predicted Label: Lung_Opacity
#   True Label: Lung_Opacity
#   Correct: True
# ------------------------------
# File 4225:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 4226:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 4227:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 4228:
#   Predicted Label: Lung_Opacity
#   True Label: Lung_Opacity
#   Correct: True
# ------------------------------
# File 4229:
#   Predicted Label: Normal
#   True Label: Normal
#   Correct: True
# ------------------------------
# File 4230:
#   Predicted Label: Lung_Opacity
#   True Label: Lung_Opacity
#   Correct: True
# ------------------------------
# File 4231:
#   Predicted Label: Lung_Opacity
#   True Label: Lung_Opacity
#   Correct: True
# ------------------------------
# File 4232:
#   Predicted Label: Normal
#   True Label: Lung_Opacity
#   Correct: False
# ------------------------------
# File 4233:
#   Predicted Label: COVID
#   True Label: COVID
#   Correct: True
# ------------------------------

# %%
import os

# Path to the dataset files
base_path = "/root/.cache/kagglehub/datasets/tawsifurrahman/covid19-radiography-database/versions/5"

# List directories in the base path to verify the available subsets
dataset_dirs = os.listdir(base_path)
print(f"Available directories in the dataset: {dataset_dirs}")

# List of subset directories to check
subdirectories = ["COVID", "Lung_Opacity", "Normal", "Viral Pneumonia"]

# Function to check and print image paths for each directory
def list_image_paths(base_path, subdirectories):
    for subdirectory in subdirectories:
        # Build the path to the subdirectory
        subdir_path = os.path.join(base_path, "COVID-19_Radiography_Dataset", subdirectory)

        if os.path.exists(subdir_path):
            print(f"\nListing images in the '{subdirectory}' directory:")
            # Check for 'images' subfolder in each subdirectory
            images_dir = os.path.join(subdir_path, "images")
            if os.path.exists(images_dir):
                image_files = os.listdir(images_dir)
                if image_files:
                    for image_file in image_files[:3]:  # Limit to first 3 images
                        image_path = os.path.join(images_dir, image_file)
                        print(f"  {image_path}")
                else:
                    print(f"  No images found in the '{subdirectory}/images' directory.")
            else:
                print(f"  No 'images' directory found inside the '{subdirectory}' folder.")
        else:
            print(f"  No '{subdirectory}' directory found in the 'COVID-19_Radiography_Dataset' folder.")

# Run the function to list image paths
list_image_paths(base_path, subdirectories)
# Out:
# Available directories in the dataset: ['COVID-19_Radiography_Dataset']
#
# Listing images in the 'COVID' directory:
#   /root/.cache/kagglehub/datasets/tawsifurrahman/covid19-radiography-database/versions/5/COVID-19_Radiography_Dataset/COVID/images/COVID-173.png
#   /root/.cache/kagglehub/datasets/tawsifurrahman/covid19-radiography-database/versions/5/COVID-19_Radiography_Dataset/COVID/images/COVID-820.png
#   /root/.cache/kagglehub/datasets/tawsifurrahman/covid19-radiography-database/versions/5/COVID-19_Radiography_Dataset/COVID/images/COVID-2893.png
#
# Listing images in the 'Lung_Opacity' directory:
#   /root/.cache/kagglehub/datasets/tawsifurrahman/covid19-radiography-database/versions/5/COVID-19_Radiography_Dataset/Lung_Opacity/images/Lung_Opacity-3873.png
#   /root/.cache/kagglehub/datasets/tawsifurrahman/covid19-radiography-database/versions/5/COVID-19_Radiography_Dataset/Lung_Opacity/images/Lung_Opacity-1107.png
#   /root/.cache/kagglehub/datasets/tawsifurrahman/covid19-radiography-database/versions/5/COVID-19_Radiography_Dataset/Lung_Opacity/images/Lung_Opacity-1340.png
#
# Listing images in the 'Normal' directory:
#   /root/.cache/kagglehub/datasets/tawsifurrahman/covid19-radiography-database/versions/5/COVID-19_Radiography_Dataset/Normal/images/Normal-4990.png
#   /root/.cache/kagglehub/datasets/tawsifurrahman/covid19-radiography-database/versions/5/COVID-19_Radiography_Dataset/Normal/images/Normal-5552.png
#   /root/.cache/kagglehub/datasets/tawsifurrahman/covid19-radiography-database/versions/5/COVID-19_Radiography_Dataset/Normal/images/Normal-6953.png
#
# Listing images in the 'Viral Pneumonia' directory:
#   /root/.cache/kagglehub/datasets/tawsifurrahman/covid19-radiography-database/versions/5/COVID-19_Radiography_Dataset/Viral Pneumonia/images/Viral Pneumonia-525.png
#   /root/.cache/kagglehub/datasets/tawsifurrahman/covid19-radiography-database/versions/5/COVID-19_Radiography_Dataset/Viral Pneumonia/images/Viral Pneumonia-542.png
#   /root/.cache/kagglehub/datasets/tawsifurrahman/covid19-radiography-database/versions/5/COVID-19_Radiography_Dataset/Viral Pneumonia/images/Viral Pneumonia-218.png

# %%
import os
import numpy as np
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing.image import img_to_array
from PIL import Image
import matplotlib.pyplot as plt

# Load the model
model = load_model('covid_cnn_model.keras')

# Define the image size (same as during training)
img_size = (128, 128)

# Example label_encoder, you should replace this with your actual label encoder
# This is just an example and should match your training setup
class_labels = ['COVID', 'Lung_Opacity', 'Normal', 'Viral Pneumonia']

# Directories for each class
directories = {
    'COVID': "/root/.cache/kagglehub/datasets/tawsifurrahman/covid19-radiography-database/versions/5/COVID-19_Radiography_Dataset/COVID/images",
    'Lung_Opacity': "/root/.cache/kagglehub/datasets/tawsifurrahman/covid19-radiography-database/versions/5/COVID-19_Radiography_Dataset/Lung_Opacity/images",
    'Normal': "/root/.cache/kagglehub/datasets/tawsifurrahman/covid19-radiography-database/versions/5/COVID-19_Radiography_Dataset/Normal/images",
    'Viral Pneumonia': "/root/.cache/kagglehub/datasets/tawsifurrahman/covid19-radiography-database/versions/5/COVID-19_Radiography_Dataset/Viral Pneumonia/images"
}

# Function to predict the disease from an input image
def predict_disease(image_path, true_label=None):
    try:
        # Load and preprocess the input image
        img = Image.open(image_path).convert("L")  # Convert to grayscale
        img = img.resize(img_size)  # Resize to match model input
        img_array = img_to_array(img) / 255.0  # Normalize pixel values
        img_array = np.expand_dims(img_array, axis=0)  # Add batch dimension

        # Make prediction
        predictions = model.predict(img_array)
        predicted_class = np.argmax(predictions, axis=1)[0]

        # Decode the predicted class label
        predicted_label = class_labels[predicted_class]

        return predicted_label, img
    except Exception as e:
        print(f"Error processing the image: {e}")
        return None, None

# Function to display 3 images and predictions from each directory
def display_images_in_directory(directory, true_label=None):
    image_files = os.listdir(directory)
    image_files = image_files[:3]  # Get only the first 3 images for display

    plt.figure(figsize=(12, 4))  # Adjust the size of the plot

    for i, image_file in enumerate(image_files):
        image_path = os.path.join(directory, image_file)

        predicted_label, img = predict_disease(image_path, true_label)

        if img is not None:
            plt.subplot(1, 3, i+1)  # Create a subplot with 3 images per row
            plt.imshow(img, cmap='gray')
            plt.title(f"Pred: {predicted_label}")
            plt.axis('off')  # Hide axis

    plt.suptitle(f"Predictions for {directory} Directory", fontsize=16)
    plt.show()

# Display and predict for each directory (only 3 images from each)
for label, directory in directories.items():
    print(f"\nListing and processing 3 images in the '{label}' directory:")
    display_images_in_directory(directory, true_label=label)
# Out:
# Listing and processing 3 images in the 'COVID' directory:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 314ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Listing and processing 3 images in the 'Lung_Opacity' directory:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# Listing and processing 3 images in the 'Normal' directory:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# Listing and processing 3 images in the 'Viral Pneumonia' directory:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step

# %%
# Evaluate the model
test_loss, test_accuracy,test_precision = model.evaluate(X_test, y_test)
print(f"Test Loss: {test_loss}")
print(f"Test Accuracy: {test_accuracy}")
print(f"Test Precision: {test_precision}")
# Out:
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.9055 - loss: 0.2510 - precision_1: 0.9078
# Test Loss: 0.26292845606803894
# Test Accuracy: 0.904323160648346
# Test Precision: 0.907192051410675

# %%
from sklearn.metrics import classification_report
import numpy as np

# Assuming `model` is your trained model and (X_test, y_test) is your test data
# y_test should be one-hot encoded; convert it to class labels for evaluation
y_test_classes = np.argmax(y_test, axis=1)

# Get predictions from the model
y_pred = model.predict(X_test)
y_pred_classes = np.argmax(y_pred, axis=1)

# Generate the classification report
report = classification_report(y_test_classes, y_pred_classes, target_names=subsets)
print(report)
# Out:
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step
#                  precision    recall  f1-score   support
#
#           COVID       0.93      0.94      0.94       701
#    Lung_Opacity       0.90      0.82      0.85      1246
#          Normal       0.89      0.94      0.91      2024
# Viral Pneumonia       0.96      0.97      0.96       262
#
#        accuracy                           0.90      4233
#       macro avg       0.92      0.92      0.92      4233
#    weighted avg       0.90      0.90      0.90      4233
